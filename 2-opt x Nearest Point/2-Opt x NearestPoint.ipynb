# %%
import folium
import geopy
from geopy.geocoders import Nominatim
from geopy.distance import geodesic
import pandas as pd
import numpy as np
import math

# %%
from geopy.geocoders import ArcGIS

# %%
class Point:
    def __init__(self, index, latitude, longitude):
        self.index = index
        self.latitude = latitude
        self.longitude = longitude

# %%
points = []
points.clear()
csv = pd.read_csv("Coordinates.csv")
for index, row in csv.iterrows():
    latitude = row['latitude']
    longitude = row['longitude']
    points.append(Point(index, latitude, longitude))

# %%
Map = folium.Map(location=[points[0].latitude, points[0].longitude], zoom_start=12)

# %%
def distance(point1, point2):
    return geodesic((point1.latitude, point1.longitude), (point2.latitude, point2.longitude)).kilometers

# %%
def totalDistance(order):
    totalDistance = 0
    numPoints = len(order)
    for i in range(numPoints - 1):
        point1 = order[i]
        point2 = order[i + 1]
        distance1 = distance(point1, point2)
        totalDistance += distance1
    toBeginning = distance(order[-1], order[0])
    totalDistance += toBeginning
    return totalDistance

# %%
def makeDistMatrix(points):
    numPoints = len(points)
    matrix = np.zeros((numPoints, numPoints))

    for i in range(numPoints):
        for j in range(i+1, numPoints):
            dist = distance(points[i], points[j])
            matrix[i][j] = dist
            matrix[j][i] = dist

    return matrix
distanceMatrix = makeDistMatrix(points)

# %%
def nearestPointAlgorithm(points, startPoint, distanceMatrix):
    numPoints = len(points)
    visited = [False for _ in range(numPoints)]
    unvisited = set(range(numPoints))
    path = [startPoint]
    visited[0] = True
    currentPoint = 0

    while len(path) < numPoints:
        nearestPoint = None
        nearestDistance = math.inf
        for point in range(numPoints):
            if not visited[point]:
                distance = distanceMatrix[currentPoint][point]
                if distance < nearestDistance:
                    nearestPoint = point
                    nearestDistance = distance
        currentPoint = nearestPoint
        path.append(currentPoint)
        visited[currentPoint] = True

    return path

# %%
nearestPoints = nearestPointAlgorithm(points, 0, distanceMatrix)
nearestPointPath = [points[index] for index in nearestPoints]
totalDistance(nearestPointPath)
# Out:
# 38.98291869510777

# %%
for point in points:
    folium.Marker(
        location=[point.latitude, point.longitude],
        popup=(point.latitude, point.longitude),
        icon=folium.Icon(color='blue', icon='map-marker')).add_to(Map)
polylineCoordinates = [(point.latitude, point.longitude) for point in nearestPointPath]
folium.PolyLine(polylineCoordinates, color='green').add_to(Map)
    
Map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_43f2f99cd2f296070c4b94aa512acfb5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_43f2f99cd2f296070c4b94aa512acfb5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_43f2f99cd2f296070c4b94aa512acfb5 = L.map(
#                 &quot;map_43f2f99cd2f296070c4b94aa512acfb5&quot;,
#                 {
#                     center: [-0.8728407052200818, 36.3385063300631],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ee0c75b17ad40c8756cca8ba8b1d3ded = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_43f2f99cd2f296070c4b94aa512acfb5);
#
#
#             var marker_249efecb2637fb50d2d94cfc80c01b65 = L.marker(
#                 [-0.8728407052200818, 36.3385063300631],
#                 {}
#             ).addTo(map_43f2f99cd2f296070c4b94aa512acfb5);
#
#
#             var icon_54ce0132e99bba765d6d42940444f548 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;map-marker&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_249efecb2637fb50d2d94cfc80c01b65.setIcon(icon_54ce0132e99bba765d6d42940444f548);
#
#
#         var popup_eb3186b0644fa8cfddfcc95e04966aa7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_14ba699618700fdc7a23e800216c427b = $(`&lt;div id=&quot;html_14ba699618700fdc7a23e800216c427b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(-0.8728407052200818, 36.3385063300631)&lt;/div&gt;`)[0];
#                 popup_eb3186b0644fa8cfddfcc95e04966aa7.setContent(html_14ba699618700fdc7a23e800216c427b);
#
#
#
#         marker_249efecb2637fb50d2d94cfc80c01b65.bindPopup(popup_eb3186b0644fa8cfddfcc95e04966aa7)
#         ;
#
#
#
#
#             var marker_d0c138661caf739fca2bdb5d2425855e = L.marker(
#                 [-0.8799744193313597, 36.344520866492246],
#                 {}
#             ).addTo(map_43f2f99cd2f296070c4b94aa512acfb5);
#
#
#             var icon_cab90d198d9d7bae92ba806869792137 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;map-marker&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d0c138661caf739fca2bdb5d2425855e.setIcon(icon_cab90d198d9d7bae92ba806869792137);
#
#
#         var popup_a63c639fbd64f86f383714335f299c02 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0a833337067305e44ca93c6256dbc3a0 = $(`&lt;div id=&quot;html_0a833337067305e44ca93c6256dbc3a0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(-0.8799744193313597, 36.344520866492246)&lt;/div&gt;`)[0];
#                 popup_a63c639fbd64f86f383714335f299c02.setContent(html_0a833337067305e44ca93c6256dbc3a0);
#
#
#
#         marker_d0c138661caf739fca2bdb5d2425855e.bindPopup(popup_a63c639fbd64f86f383714335f299c02)
#         ;
#
#
#
#
#             var marker_685f84e6cf8b4ca94e5186291cbc9c10 = L.marker(
#                 [-0.8835755325543759, 36.334387720551234],
#                 {}
#             ).addTo(map_43f2f99cd2f296070c4b94aa512acfb5);
#
#
#             var icon_9b228610a085350a4b07a861b0417c92 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;map-marker&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_685f84e6cf8b4ca94e5186291cbc9c10.setIcon(icon_9b228610a085350a4b07a861b0417c92);
#
#
#         var popup_28f4dfbc19b2169595cc628136dd4515 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1611f35b74136693c7249ab3ee8463b3 = $(`&lt;div id=&quot;html_1611f35b74136693c7249ab3ee8463b3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(-0.8835755325543759, 36.334387720551234)&lt;/div&gt;`)[0];
#                 popup_28f4dfbc19b2169595cc628136dd4515.setContent(html_1611f35b74136693c7249ab3ee8463b3);
#
#
#
#         marker_685f84e6cf8b4ca94e5186291cbc9c10.bindPopup(popup_28f4dfbc19b2169595cc628136dd4515)
#         ;
#
#
#
#
#             var marker_3a26f5e4cddfd7452bebb3db9ae5785a = L.marker(
#                 [-0.8837586400092997, 36.32944323376631],
#                 {}
#             ).addTo(map_43f2f99cd2f296070c4b94aa512acfb5);

# %%
def twoOptStupid(points, maxIterationsWithoutImprovement):
    bestDistance = totalDistance(points)
    iterationsWithoutImprovement = 0
    count = 0
    
    while iterationsWithoutImprovement < maxIterationsWithoutImprovement:
        improved = False
        for i in range(1, len(points) - 1):
            for j in range(i + 1, len(points)):
                count += 1
                newPath = points.copy()
                newPath[i:j] = points[j-1:i-1:-1]
                newDistance = totalDistance(newPath)
                #print(newDistance - bestDistance)
                if newDistance < bestDistance:
                    points = newPath
                    bestDistance = newDistance
                    improved = True
                    iterationsWithoutImprovement = 0
                if not improved:
                    iterationsWithoutImprovement += 1
    print(count)
    return points

# %%
path = twoOptStupid(points, 10)
print(totalDistance(path))
# Out:
# 1134
# 36.73266132724645

# %%
def twoOpt(points, maxIterationsWithoutImprovement):
    iterationsWithoutImprovement = 0
    count = 0
    while iterationsWithoutImprovement < maxIterationsWithoutImprovement:
        improved = False
        for i in range(1, len(points) - 1):
            for j in range(i + 1, len(points)):
                count += 1
                newPath = points.copy()
                
                #print('old path------------')
                #for p in newPath:
                #    print(p.index)

                newPath[i:j] = points[j-1:i-1:-1]
                #swaps the points from i inclusive to j exclusive i.e 1,2,3,4,5 where i = 1 j = 4 becomes 1,4,3,2,5

                
                #print('new ------------')
                #for p in newPath:
                #    print(p.index)
                
                oldDistance = distance(points[i - 1], points[i]) + distance(points[j - 1], points[j])
                newDistance = distance(points[i - 1], points[j - 1]) + distance(points[i], points[j])
                a = oldDistance - newDistance

                oldTotalDis = totalDistance(points)
                newTotalDis = totalDistance(newPath)
                b = oldTotalDis - newTotalDis
                
                if abs(a - b) > 0.000001:
                    print ("error " + str(a - b))
                
                #print(oldDistance)
                #print(newDistance)
                if newDistance < oldDistance:
                    points = newPath
                    improved = True
                    iterationsWithoutImprovement = 0
                if not improved:
                    iterationsWithoutImprovement += 1
    print(count)
    return points

# %%
path2 = twoOpt(nearestPointPath, 10)
print(totalDistance(path2))
# Out:
# 756
# 36.55518440556278

# %%
pointPath = [[point.latitude, point.longitude] for point in path]

# %%
Map = folium.Map(location=[points[0].latitude, points[0].longitude], zoom_start=12)
for point in points:
    folium.Marker(
        location=[point.latitude, point.longitude],
        popup=(point.latitude, point.longitude),
        icon=folium.Icon(color='blue', icon='map-marker')).add_to(Map)
polylineCoordinates = [(point.latitude, point.longitude) for point in path]
folium.PolyLine(polylineCoordinates, color='green').add_to(Map)
folium.Marker(location = [points[0].latitude, points[0].longitude], 
                  popup = [points[0].latitude, points[0].longitude, 0], 
                  icon=folium.Icon(color='red', icon='map-marker')).add_to(Map)
    
Map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0ac8938c4af45b87dc4ecf9dd067f7ce {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0ac8938c4af45b87dc4ecf9dd067f7ce&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0ac8938c4af45b87dc4ecf9dd067f7ce = L.map(
#                 &quot;map_0ac8938c4af45b87dc4ecf9dd067f7ce&quot;,
#                 {
#                     center: [-0.8728407052200818, 36.3385063300631],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_75bd5e7f8ca579b000a1a77a9c6987fc = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0ac8938c4af45b87dc4ecf9dd067f7ce);
#
#
#             var marker_6bc8ea890536be81922de0b553e8af97 = L.marker(
#                 [-0.8728407052200818, 36.3385063300631],
#                 {}
#             ).addTo(map_0ac8938c4af45b87dc4ecf9dd067f7ce);
#
#
#             var icon_3b8685c26cfadc2a97bd04aa6ee9db1b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;map-marker&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_6bc8ea890536be81922de0b553e8af97.setIcon(icon_3b8685c26cfadc2a97bd04aa6ee9db1b);
#
#
#         var popup_bbfb0ed09622c85bdda25aa5900508f1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8c5abba4dccae2d5e50c9f51bcbd4c82 = $(`&lt;div id=&quot;html_8c5abba4dccae2d5e50c9f51bcbd4c82&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(-0.8728407052200818, 36.3385063300631)&lt;/div&gt;`)[0];
#                 popup_bbfb0ed09622c85bdda25aa5900508f1.setContent(html_8c5abba4dccae2d5e50c9f51bcbd4c82);
#
#
#
#         marker_6bc8ea890536be81922de0b553e8af97.bindPopup(popup_bbfb0ed09622c85bdda25aa5900508f1)
#         ;
#
#
#
#
#             var marker_34a7c3d3f9dc1bf3f1e581298f58c7f8 = L.marker(
#                 [-0.8799744193313597, 36.344520866492246],
#                 {}
#             ).addTo(map_0ac8938c4af45b87dc4ecf9dd067f7ce);
#
#
#             var icon_374ff30ffaf6069f40804887eb7ceb59 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;map-marker&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_34a7c3d3f9dc1bf3f1e581298f58c7f8.setIcon(icon_374ff30ffaf6069f40804887eb7ceb59);
#
#
#         var popup_8a21dd1376a7eebaf16ffea5c400267e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d3b58b7e33d2852c78388bd86a8e7050 = $(`&lt;div id=&quot;html_d3b58b7e33d2852c78388bd86a8e7050&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(-0.8799744193313597, 36.344520866492246)&lt;/div&gt;`)[0];
#                 popup_8a21dd1376a7eebaf16ffea5c400267e.setContent(html_d3b58b7e33d2852c78388bd86a8e7050);
#
#
#
#         marker_34a7c3d3f9dc1bf3f1e581298f58c7f8.bindPopup(popup_8a21dd1376a7eebaf16ffea5c400267e)
#         ;
#
#
#
#
#             var marker_d3733163d5a8a88f189915788d55c801 = L.marker(
#                 [-0.8835755325543759, 36.334387720551234],
#                 {}
#             ).addTo(map_0ac8938c4af45b87dc4ecf9dd067f7ce);
#
#
#             var icon_402d9410c8ebd103b5911f2138859711 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;map-marker&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d3733163d5a8a88f189915788d55c801.setIcon(icon_402d9410c8ebd103b5911f2138859711);
#
#
#         var popup_30781afa8298a9fee5b3f523a9433947 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_039c0a84e85b3b4692f5185a3819875a = $(`&lt;div id=&quot;html_039c0a84e85b3b4692f5185a3819875a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(-0.8835755325543759, 36.334387720551234)&lt;/div&gt;`)[0];
#                 popup_30781afa8298a9fee5b3f523a9433947.setContent(html_039c0a84e85b3b4692f5185a3819875a);
#
#
#
#         marker_d3733163d5a8a88f189915788d55c801.bindPopup(popup_30781afa8298a9fee5b3f523a9433947)
#         ;
#
#
#
#
#             var marker_e2e93af118e660ad35ae1cc5ef52bc14 = L.marker(
#                 [-0.8837586400092997, 36.32944323376631],
#                 {}
#             ).addTo(map_0ac8938c4af45b87dc4ecf9dd067f7ce);

# %%
Map = folium.Map(location=[points[0].latitude, points[0].longitude], zoom_start=12)

# %%
for point in points:
    folium.Marker(
        location=[point.latitude, point.longitude],
        popup=(point.latitude, point.longitude),
        icon=folium.Icon(color='blue', icon='map-marker')).add_to(Map)
polylineCoordinates = [(point.latitude, point.longitude) for point in path2]
folium.PolyLine(polylineCoordinates, color='green').add_to(Map)
folium.Marker(location = [points[0].latitude, points[0].longitude], 
                  popup = [points[0].latitude, points[0].longitude, 0], 
                  icon=folium.Icon(color='red', icon='map-marker')).add_to(Map)
    
Map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8378bc8484b45be33409ed56c2000771 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8378bc8484b45be33409ed56c2000771&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8378bc8484b45be33409ed56c2000771 = L.map(
#                 &quot;map_8378bc8484b45be33409ed56c2000771&quot;,
#                 {
#                     center: [-0.8728407052200818, 36.3385063300631],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c50647c06ffb2a9f17cbf0c93e45120c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8378bc8484b45be33409ed56c2000771);
#
#
#             var marker_912a6d4e150fa46e697418761f812c84 = L.marker(
#                 [-0.8728407052200818, 36.3385063300631],
#                 {}
#             ).addTo(map_8378bc8484b45be33409ed56c2000771);
#
#
#             var icon_48019e670df4a8c99571e0741b150b94 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;map-marker&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_912a6d4e150fa46e697418761f812c84.setIcon(icon_48019e670df4a8c99571e0741b150b94);
#
#
#         var popup_34043f7ad48e90dc0feb1e80b07650ed = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_47a2daf6607d9ab67d9d6dfa2d7fbefe = $(`&lt;div id=&quot;html_47a2daf6607d9ab67d9d6dfa2d7fbefe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(-0.8728407052200818, 36.3385063300631)&lt;/div&gt;`)[0];
#                 popup_34043f7ad48e90dc0feb1e80b07650ed.setContent(html_47a2daf6607d9ab67d9d6dfa2d7fbefe);
#
#
#
#         marker_912a6d4e150fa46e697418761f812c84.bindPopup(popup_34043f7ad48e90dc0feb1e80b07650ed)
#         ;
#
#
#
#
#             var marker_94acea901f38dd50df3d38415a05a224 = L.marker(
#                 [-0.8799744193313597, 36.344520866492246],
#                 {}
#             ).addTo(map_8378bc8484b45be33409ed56c2000771);
#
#
#             var icon_4c510fad143ae68733c46de11577e35e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;map-marker&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_94acea901f38dd50df3d38415a05a224.setIcon(icon_4c510fad143ae68733c46de11577e35e);
#
#
#         var popup_4e39536c27e5fab1b6e862590e7a8f6e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3cae321e6d5fcc95fc12c60d0b19c809 = $(`&lt;div id=&quot;html_3cae321e6d5fcc95fc12c60d0b19c809&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(-0.8799744193313597, 36.344520866492246)&lt;/div&gt;`)[0];
#                 popup_4e39536c27e5fab1b6e862590e7a8f6e.setContent(html_3cae321e6d5fcc95fc12c60d0b19c809);
#
#
#
#         marker_94acea901f38dd50df3d38415a05a224.bindPopup(popup_4e39536c27e5fab1b6e862590e7a8f6e)
#         ;
#
#
#
#
#             var marker_e7494d24b5fd4f723d5753026e04af4e = L.marker(
#                 [-0.8835755325543759, 36.334387720551234],
#                 {}
#             ).addTo(map_8378bc8484b45be33409ed56c2000771);
#
#
#             var icon_c0ffc4ff8a7119359008967124632348 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;map-marker&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e7494d24b5fd4f723d5753026e04af4e.setIcon(icon_c0ffc4ff8a7119359008967124632348);
#
#
#         var popup_a7faf4d0ce27f88a04c32b135ba73374 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1c74330c0647e562197624b9f4aa175f = $(`&lt;div id=&quot;html_1c74330c0647e562197624b9f4aa175f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(-0.8835755325543759, 36.334387720551234)&lt;/div&gt;`)[0];
#                 popup_a7faf4d0ce27f88a04c32b135ba73374.setContent(html_1c74330c0647e562197624b9f4aa175f);
#
#
#
#         marker_e7494d24b5fd4f723d5753026e04af4e.bindPopup(popup_a7faf4d0ce27f88a04c32b135ba73374)
#         ;
#
#
#
#
#             var marker_0eb8b6fec84008ddc6d9ad510d6cceb4 = L.marker(
#                 [-0.8837586400092997, 36.32944323376631],
#                 {}
#             ).addTo(map_8378bc8484b45be33409ed56c2000771);
